# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("Reviews.csv",nrows=1000)
df.head(3)
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      1000 non-null   int64
#  1   ProductId               1000 non-null   object
#  2   UserId                  1000 non-null   object
#  3   ProfileName             1000 non-null   object
#  4   HelpfulnessNumerator    1000 non-null   int64
#  5   HelpfulnessDenominator  1000 non-null   int64
#  6   Score                   1000 non-null   int64
#  7   Time                    1000 non-null   int64
#  8   Summary                 1000 non-null   object
#  9   Text                    1000 non-null   object
# dtypes: int64(5), object(5)
# memory usage: 78.3+ KB

# %%
df.Summary.head()
# Out:
# 0    Good Quality Dog Food
# 1        Not as Advertised
# 2    "Delight" says it all
# 3           Cough Medicine
# 4              Great taffy
# Name: Summary, dtype: object

# %%
df.Text.head()
# Out:
# 0    I have bought several of the Vitality canned d...
# 1    Product arrived labeled as Jumbo Salted Peanut...
# 2    This is a confection that has been around a fe...
# 3    If you are looking for the secret ingredient i...
# 4    Great taffy at a great price.  There was a wid...
# Name: Text, dtype: object

# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in /opt/anaconda3/lib/python3.12/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /opt/anaconda3/lib/python3.12/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from nltk>=3.9->textblob) (4.66.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
from nltk.corpus import stopwords
from textblob import TextBlob
from textblob import Word
# Lower casing and removing punctuations
df ['Text'] = df[ 'Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df ['Text'] = df['Text'].str. replace('[^\w\s]','')
stop = stopwords.words('english')
df ['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop) )

df ['Text'] = df['Text'].apply(lambda x: str(TextBlob(x).correct ()))
df ['Text'] = df['Text'].apply(lambda x: " ".join([Word(word).lemmatize()for word in x.split()]))
df.Text.head()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# <>:7: SyntaxWarning: invalid escape sequence '\w'
# /var/folders/cb/x15d8_k92fb74fb2d2lv8b4c0000gn/T/ipykernel_2699/1623360529.py:7: SyntaxWarning: invalid escape sequence '\w'
#   df ['Text'] = df['Text'].str. replace('[^\w\s]','')
# /var/folders/cb/x15d8_k92fb74fb2d2lv8b4c0000gn/T/ipykernel_2699/1623360529.py:7: SyntaxWarning: invalid escape sequence '\w'
#   df ['Text'] = df['Text'].str. replace('[^\w\s]','')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 11
#       8 stop = stopwords.words('english')
#       9 df ['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop) )
# ---> 11 df ['Text'] = df['Text'].apply(lambda x: str(TextBlob(x).correct ()))
#      12 df ['Text'] = df['Text'].apply(lambda x: " ".join([Word(word).lemmatize()for word in x.split()]))
#      13 df.Text.head()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[54], line 11, in <lambda>(x)
#       8 stop = stopwords.words('english')
#       9 df ['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop) )
# ---> 11 df ['Text'] = df['Text'].apply(lambda x: str(TextBlob(x).correct ()))
#      12 df ['Text'] = df['Text'].apply(lambda x: " ".join([Word(word).lemmatize()for word in x.split()]))
#      13 df.Text.head()
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/blob.py:555, in BaseBlob.correct(self)
#     553 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
#     554 corrected = (Word(w).correct() for w in tokens)
# --> 555 ret = "".join(corrected)
#     556 return self.__class__(ret)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/blob.py:554, in <genexpr>(.0)
#     552 # regex matches: word or punctuation or whitespace
#     553 tokens = nltk.tokenize.regexp_tokenize(self.raw, r"\w+|[^\w\s]|\s")
# --> 554 corrected = (Word(w).correct() for w in tokens)
#     555 ret = "".join(corrected)
#     556 return self.__class__(ret)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/blob.py:115, in Word.correct(self)
#     109 def correct(self):
#     110     """Correct the spelling of the word. Returns the word with the highest
#     111     confidence using the spelling corrector.
#     112
#     113     .. versionadded:: 0.6.0
#     114     """
# --> 115     return Word(self.spellcheck()[0][0])
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/blob.py:107, in Word.spellcheck(self)
#      98 def spellcheck(self):
#      99     """Return a list of (word, confidence) tuples of spelling corrections.
#     100
#     101     Based on: Peter Norvig, "How to Write a Spelling Corrector"
#    (...)
#     105     .. versionadded:: 0.6.0
#     106     """
# --> 107     return suggest(self.string)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/en/__init__.py:118, in suggest(w)
#     116 def suggest(w):
#     117     """Returns a list of (word, confidence)-tuples of spelling corrections."""
# --> 118     return spelling.suggest(w)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/_text.py:1692, in Spelling.suggest(self, w)
#    1687 if w.replace(".", "").isdigit():
#    1688     return [(w, 1.0)]  # 1.5
#    1689 candidates = (
#    1690     self._known([w])
#    1691     or self._known(self._edit1(w))
# -> 1692     or self._known(self._edit2(w))
#    1693     or [w]
#    1694 )
#    1695 candidates = [(self.get(c, 0.0), c) for c in candidates]
#    1696 s = float(sum(p for p, word in candidates) or 1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/_text.py:1667, in Spelling._edit2(self, w)
#    1664 """Returns a set of words with edit distance 2 from the given word"""
#    1665 # Of all spelling errors, 99% is covered by edit distance 2.
#    1666 # Only keep candidates that are actually known words (20% speedup).
# -> 1667 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/_text.py:1667, in <genexpr>(.0)
#    1664 """Returns a set of words with edit distance 2 from the given word"""
#    1665 # Of all spelling errors, 99% is covered by edit distance 2.
#    1666 # Only keep candidates that are actually known words (20% speedup).
# -> 1667 return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/_text.py:104, in lazydict.__contains__(self, *args)
#     103 def __contains__(self, *args):
# --> 104     return self._lazy("__contains__", *args)
#
# File /opt/anaconda3/lib/python3.12/site-packages/textblob/_text.py:85, in lazydict._lazy(self, method, *args)
#      80 def load(self):
#      81     # Must be overridden in a subclass.
#      82     # Must load data with dict.__setitem__(self, k, v) instead of lazydict[k] = v.
#      83     pass
# ---> 85 def _lazy(self, method, *args):
#      86     """If the dictionary is empty, calls lazydict.load().
#      87     Replaces lazydict.method() with dict.method() and calls it.
#      88     """
#      89     if dict.__len__(self) == 0:
#
# KeyboardInterrupt:

# %%
reviews = df
reviews.dropna(inplace=True)
reviews.Score.hist(bins=5,grid=False)
plt.show()
print(reviews.groupby('Score').count().Id)

# %%
score_1=reviews[reviews['Score']==1].sample(n=47)
score_2=reviews[reviews['Score']==2].sample(n=47)
score_3=reviews[reviews['Score']==3].sample(n=47)
score_4=reviews[reviews['Score']==4].sample(n=47)
score_5=reviews[reviews['Score']==5].sample(n=47)

# %%
reviews_sample=pd.concat([score_1,score_2,score_3,score_4,score_5],axis=0)
reviews_sample.reset_index(drop=True,inplace=True)

print(reviews_sample.groupby('Score').count().Id)
# Out:
# Score
# 1    47
# 2    47
# 3    47
# 4    47
# 5    47
# Name: Id, dtype: int64

# %%
from wordcloud import WordCloud
reviews_str = " ".join(reviews_sample ["Summary"]. to_numpy ())
wordcloud = WordCloud (background_color='white') .generate(reviews_str)
plt.figure(figsize=(10,10))
plt. imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
